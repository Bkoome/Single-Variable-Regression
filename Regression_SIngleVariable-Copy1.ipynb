# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
house_data=pd.read_csv('homeprices.csv')

# %%
house_data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("House Area")
plt.ylabel("House Price")
plt.scatter(house_data.area, house_data.price, color='r', marker='+')

# %%
regression=linear_model.LinearRegression() #define linear regression object
regression.fit(house_data[["area"]],house_data.price) #1ist fit a 2D array
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regression.predict(3900)
# Out:
# array([710188.35616438])

# %%
regression.coef_
# Out:
# array([135.78767123])

# %%
regression.intercept_
# Out:
# 180616.43835616432

# %%
plt.figure(figsize=(10,10))
plt.xlabel('Area', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.scatter(house_data.area, house_data.price, color='r', marker='+')
plt.plot(h_areas, regression.predict(h_areas), color='blue')
#plt.show()

# %%
h_areas=pd.read_csv("areas.csv")
h_areas
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
h_predicted=regression.predict(h_areas)

# %%
h_predicted

# %%
h_areas['predicted prices']=h_predicted

# %%
h_areas

# %%
h_areas.to_csv('Predicted_prices.csv',index=True)
